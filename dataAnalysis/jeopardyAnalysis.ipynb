# %% [markdown]
# # Data analysis for the jeopardy dataset
#
# ## Read and process the data
#
# ### Import necessary modules

# %%
import json
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import plotly.express as px

# %%
path = r"data/JEOPARDY_QUESTIONS.json"
jeopardy_questions = json.load(open(path, "r"))

# %%
f"Number of questions: {len(jeopardy_questions)}"
# Out:
# 'Number of questions: 216930'

# %%
categories = list(set(question.get("category", "No category") for question in jeopardy_questions))
sample_categories = ', \n'.join(random.choices(categories, k=10))
print(f"Number of unique categories: {len(categories)}. \nFor example: \n{sample_categories}")
# Out:
# Number of unique categories: 27995.
# For example:
# 1812,
# NICE WORK IF YOU CAN GET IT,
# ON A SWISS ARMY KNIFE,
# OSCAR-WINNING SONGS,
# WINGS,
# "DEC" ME,
# WE WANT PISA!,
# TV & MOVIE ACTORS,
# OBJETS D'ART,
# THE 2011 EMMYS

# %%
samples_per_category = {c: [] for c in categories}
for question in jeopardy_questions: samples_per_category[question.get("category", "No category")].append(question["question"])
nSamples_per_category = {c: len(s) for c, s in samples_per_category.items()}
nSamples_per_category = sorted(nSamples_per_category.items(), key=lambda item: item[1], reverse=True)
nMostProminentClasses = 10
mostProminentClasses = nSamples_per_category[:nMostProminentClasses]
mostProminentClasses
# Out:
# [('BEFORE & AFTER', 547),
#  ('SCIENCE', 519),
#  ('LITERATURE', 496),
#  ('AMERICAN HISTORY', 418),
#  ('POTPOURRI', 401),
#  ('WORLD HISTORY', 377),
#  ('WORD ORIGINS', 371),
#  ('COLLEGES & UNIVERSITIES', 351),
#  ('HISTORY', 349),
#  ('SPORTS', 342)]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


data = {topic: samples_per_category[topic] for topic, count in mostProminentClasses}
# Flatten data and labels for encoding
texts = [text for texts_list in data.values() for text in texts_list]
labels = [key for key, texts_list in data.items() for _ in texts_list]

# Step 1: Vectorize texts using TF-IDF (or embeddings if available)
tfidf_vectorizer = TfidfVectorizer()
tfidf_vectors = tfidf_vectorizer.fit_transform(texts)

# Step 2: Dimensionality Reduction
# First reduce with PCA for better t-SNE results
pca = PCA(n_components=30)
pca_result = pca.fit_transform(tfidf_vectors.toarray())

# Step 2: Dimensionality Reduction with t-SNE
tsne = TSNE(n_components=3, perplexity=5, n_iter=300)  # Use 3 components for 3D
tsne_result = tsne.fit_transform(pca_result)
# Out:
# C:\Users\mhuep\.conda\envs\jaNoMi\lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.

# %%
import plotly.io as pio
# %matplotlib qt

# Identify prominent feature (highest-weighted term in TF-IDF) for each text
feature_names = tfidf_vectorizer.get_feature_names_out()
prominent_features = [
    feature_names[np.argmax(vec.toarray())] for vec in tfidf_vectors
]

# Step 3: Create interactive plot with Plotly
fig = px.scatter(
    x=tsne_result[:, 0], y=tsne_result[:, 1],
    color=labels,
    hover_name=texts,  # Text displayed on hover
    hover_data={'Prominent Feature': prominent_features}
)

fig.update_layout(
    title="Interactive Text Sample Clustering by Category",
    xaxis_title="TSNE Dimension 1",
    yaxis_title="TSNE Dimension 2"
)

fig.show()
# Out:
# <div>                            <div id="633b3d54-a440-4710-b5a0-e64790b2ee35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("633b3d54-a440-4710-b5a0-e64790b2ee35")) {                    Plotly.newPlot(                        "633b3d54-a440-4710-b5a0-e64790b2ee35",                        [{"customdata":[["jason"],["ericson"],["profile"],["cornucopia"],["caught"],["shedding"],["intervention"],["bouncy"],["abc"],["florida"],["amour"],["dawson"],["disappears"],["guru"],["burgess"],["keene"],["otis"],["dear"],["miniseries"],["zombie"],["mamie"],["hanks"],["die"],["democratic"],["greenville"],["culture"],["seal"],["brokerage"],["gatling"],["anthology"],["milne"],["sax"],["instructor"],["exclamation"],["dogpatch"],["deeeee"],["815"],["garp"],["schoolhouse"],["menu"],["chronicles"],["albums"],["lancaster"],["1740s"],["eminem"],["companies"],["reservoir"],["calorie"],["cooking"],["oriole"],["entrance"],["carey"],["antarctic"],["bad"],["35th"],["wacky"],["interned"],["ripley"],["imperial"],["tumbleweeds"],["pastry"],["chuck"],["mini"],["gibbon"],["achy"],["bette"],["bio"],["gamekeeper"],["aldonza"],["bloomed"],["guided"],["dynastic"],["chasez"],["mcferrin"],["bingo"],["halen"],["menlo"],["janeway"],["greeley"],["shiny"],["ricky"],["eighth"],["sheindlin"],["happy"],["daylight"],["schmancy"],["grenade"],["celebrities"],["legally"],["mcgregor"],["dinosaurs"],["surpassed"],["fairness"],["kid"],["springsteen"],["especially"],["breyer"],["cindy"],["dragnet"],["rotten"],["caviar"],["benefits"],["gooding"],["ringmaster"],["stung"],["smiling"],["duran"],["pined"],["rvs"],["longitudinal"],["admits"],["ga"],["minster"],["arthropod"],["tv"],["silver"],["dream"],["convicts"],["louisville"],["abbey"],["reporter"],["60s"],["butch"],["anchored"],["ozymandias"],["telephone"],["bandit"],["macedonian"],["plague"],["owner"],["bigot"],["chipmunks"],["lollipop"],["cellist"],["maggie"],["dumps"],["bennie"],["extra"],["chew"],["sewell"],["tatum"],["eyed"],["untouchable"],["fossil"],["collaborative"],["critter"],["seminoles"],["flag"],["yarn"],["gotti"],["farm"],["lestat"],["disaffected"],["miracles"],["discussion"],["access"],["hated"],["howled"],["hearts"],["shoo"],["stops"],["chaired"],["bicameral"],["adventureland"],["arc"],["amber"],["president"],["relaxes"],["citrus"],["apollo"],["lingerie"],["deux"],["deliver"],["arkansas"],["anymore"],["ab"],["cost"],["servicemen"],["coyote"],["fizzy"],["aspect"],["dylan"],["botticelli"],["livin"],["shortest"],["dollar"],["hood"],["baywatch"],["hideous"],["credit"],["broomstick"],["styles"],["tall"],["licensed"],["blondie"],["avian"],["adults"],["benedict"],["bodyguard"],["mm"],["collector"],["back"],["distributor"],["gothic"],["iraqi"],["berets"],["chatterley"],["chronicled"],["skywritten"],["collected"],["dying"],["elinor"],["bronson"],["bar"],["corridors"],["carpets"],["rolling"],["macbeth"],["barbarian"],["yankovic"],["deacon"],["karol"],["psychedelic"],["golly"],["correspondent"],["three"],["interior"],["evident"],["butter"],["president"],["surf"],["bunch"],["stranger"],["paradise"],["spurs"],["careers"],["buckeye"],["canvas"],["watch"],["belongings"],["pilot"],["broadway"],["grim"],["cleese"],["elvis"],["sleeping"],["salieri"],["bonham"],["crawford"],["150th"],["brutal"],["enameled"],["andy"],["tomboyish"],["primo"],["goods"],["diner"],["relocates"],["halloween"],["herbs"],["ernie"],["cosmetics"],["communicator"],["nets"],["autobots"],["mulberry"],["fans"],["rollin"],["portly"],["planetary"],["alger"],["bubbles"],["city"],["64"],["daffy"],["ain"],["colonialist"],["grayson"],["screwtape"],["composed"],["gritty"],["legged"],["conspirator"],["chili"],["crouching"],["pit"],["casino"],["pro"],["stendhal"],["grapevine"],["ari"],["melville"],["cosby"],["mcgrath"],["edible"],["artisti ...

# %%
from sentence_transformers import SentenceTransformer
# Step 1: Encode text samples using Sentence-BERT
model = SentenceTransformer('all-MiniLM-L6-v2')  # Use a lightweight model
sentence_embeddings = model.encode(texts)

# Step 2: Dimensionality Reduction with PCA and t-SNE
pca = PCA(n_components=5)
pca_result = pca.fit_transform(sentence_embeddings)

tsne = TSNE(n_components=2, perplexity=5, n_iter=300)
tsne_result = tsne.fit_transform(pca_result)

# Step 3: Create interactive plot with Plotly
fig = px.scatter(
    x=tsne_result[:, 0], y=tsne_result[:, 1],
    color=labels,
    hover_name=texts  # Text displayed on hover
)

fig.update_layout(
    title="Text Sample Clustering by Category with Sentence-BERT",
    xaxis_title="TSNE Dimension 1",
    yaxis_title="TSNE Dimension 2"
)

fig.show()
# Out:
# C:\Users\mhuep\.conda\envs\jaNoMi\lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
# <div>                            <div id="c323f32e-9174-4a74-aad1-844059905811" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c323f32e-9174-4a74-aad1-844059905811")) {                    Plotly.newPlot(                        "c323f32e-9174-4a74-aad1-844059905811",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=BEFORE & AFTER\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["'1980 scarefest in which mom & daughter switch bodies one day & are stalked by Jason at Camp Crystal Lake'","'Leif Ericson's dad who was a huge star with low surface temperature'","'Fictional girl sleuth who's the granddaughter of \"The Great Profile\"'","'Projection at the southern tip of South America also called a cornucopia'","'\"Lethal Weapon\" director whose group was caught in a Sierra Nevada pass in the winter of 1846-47'","'\"Thin\" piece of disputed Israeli-Palestinian land involved in a clothes-shedding card game'","'Film legend who became an 1823 edict against European intervention in the Western Hemisphere'","'\"Bouncy\" 1965 Beatles album that took over for Don Cornelius as host of a dance show'","'Robert E. Lee's \"right arm\" general who sang \"ABC\" with a singing group'","'1935 \"lunar\" Florida song that turned into an '80s Florida cop show'","'Singer of \"My Cherie Amour\" whose secret identity is Diana Prince'","'Morticia gets a big wet one from Richard Dawson on this ooky game show'","'Star of \"The Exorcist\" who disappears from the Maryland woods in a scary 1999 film'","'Louisa May Alcott & relationship guru John Gray collaborated on this book sequel'","'Dystopian Anthony Burgess novel that's a New Zealand fish'","'Carolyn Keene's fictional teenage detective who stars in a sitcom set in Cleveland'","'Otis Redding's No. 1 hit that's performed by a Scottish band on S-a-t-u-r-d-a-y Night'","'Novel in which Rhett Butler tells Toad, Rat & Mole, \"My dear, I don't give a damn\"'","'The Beatles' 1967 album that was a 2001 WWII miniseries on HBO'","'Van Gogh's 1889 painting of director George Romero's 1968 zombie film classic'","'Sidney Poitier movie opera that preceded Mamie Eisenhower as first lady'","'\"Wizard of Oz\" song that made it to the big screen with Tom Hanks as a hit man for the Irish mob'","'Liberator & king of Scotland who starred in \"Die Hard\"'","'Sondheim musical about a Seurat painting & the 1972 Democratic presidential nominee'","'American general who negotiated the Treaty of Greenville, earned the nickname \"Mr. Las Vegas\" & sang \"Danke Schoen\"'","'\"Culture Club\" lead singer who was \"The Father of His Country\"'","'Seal's hit song about smooching with a president's mom'","'A leading real estate brokerage firm that was a TV series starring Johnny Depp as an undercover cop'","'\"Bullet in the Head\" heavy metal rap band that's a weapon perfected by Richard Gatling in the late 19th century'","'Classic Chaucer work adapted for a 1990s TV sci-fi\u002fhorror anthology series'","'A.A. Milne boy who stole from the rich to give to the poor'","'Popular sax-playing war action figure'","'Instructor's favorite \"West End Girls\" group'","'Exclamation point who played Luke Skywalker'","'Dogpatch resident who claims to have invented baseball'","'A Grand Ole Opry star says \"How-deeeee!\" when she joins Eddie Vedder's band'","'Toronto freaks when this 1,815' landmark becomes a Medieval fortress on the North Bank of the Thames'","'Garp's literary creator who goes into songwriting with \"God Bless America\"'","'\"Schoolhouse Rock\" song about the making of laws gets to become Senate Majority Leader ...Oh yes!'","'A separate price for each dish on the menu is granted another Fren ...
